# %%
from auto_circuit.tasks import IOI_TOKEN_CIRCUIT_TASK, DOCSTRING_TOKEN_CIRCUIT_TASK, DOCSTRING_COMPONENT_CIRCUIT_TASK

from elk_experiments.auto_circuit.edge_graph import SeqGraph, sample_path_uniform, get_edge_path_counts, sample_paths, edge_in_path, valid_node, NodeType, node_name_to_type

# %%
task = DOCSTRING_COMPONENT_CIRCUIT_TASK
task.init_task()
# Out:
# Loaded pretrained model attn-only-4l into HookedTransformer
# seq_len before divergence None
# seq_len after divergence None

# %% [markdown]
# # Full Sequence Graph

# %%
graph = SeqGraph(task.model.edges, task.token_circuit, task.model.cfg.attn_only)

# %%
# check reachable
len([(v.layer, v.node_type, v.seq_idx) for v in graph.seq_nodes if v.reachable]) / len(graph.seq_nodes)
# Out:
# 1.0

# %%
# check pathcounts 
len([node for node in graph.seq_nodes if node.path_count > 0]) / len(graph.seq_nodes)
# Out:
# 1.0

# %%
# check edge in path 
len([edge for edge in task.true_edges if edge_in_path(edge, graph)]) / task.true_edge_count
# Out:
# 1.0

# %%
# check edge in path
all([not graph.valid_node(edge.dest.layer, node_name_to_type(edge.dest.name), edge.seq_idx) for edge in task.true_edges if not edge_in_path(edge, graph)])
# Out:
# True

# %%
# check edge patch counts
complement_edges = set(task.model.edges) - set(task.true_edges)
edge_path_counts = get_edge_path_counts(complement_edges, graph)
sum([v for v in edge_path_counts.values()])
# Out:
# VBox(children=(          | 0/? [00:00<?, ?it/s],))
# 656250

# %%
# check sample path uniform
path = sample_path_uniform(graph, edge_path_counts, complement_edges)
assert any(edge in complement_edges for edge in path)
[(edge, edge.seq_idx) for edge in path]
# Out:
# [(Resid Start->A0.2.K, None),
#  (A0.2->A1.4.V, None),
#  (A1.4->A2.3.K, None),
#  (A2.3->A3.1.V, None),
#  (A3.1->Resid End, None)]

# %%
sample_paths(graph, 256, complement_edges)
# Out:
# VBox(children=(          | 0/? [00:00<?, ?it/s],))
# VBox(children=(          | 0/256 [00:00<?, ?it/s],))
# [[Resid Start->A0.1.Q,
#   A0.1->A1.5.V,
#   A1.5->A2.5.Q,
#   A2.5->A3.5.K,
#   A3.5->Resid End],
#  [Resid Start->A0.4.Q,
#   A0.4->A1.3.K,
#   A1.3->A2.5.K,
#   A2.5->A3.4.V,
#   A3.4->Resid End],
#  [Resid Start->A0.7.K,
#   A0.7->A1.5.V,
#   A1.5->A2.2.K,
#   A2.2->A3.1.V,
#   A3.1->Resid End],
#  [Resid Start->A0.2.K,
#   A0.2->A1.5.K,
#   A1.5->A2.1.V,
#   A2.1->A3.1.V,
#   A3.1->Resid End],
#  [Resid Start->A0.4.K,
#   A0.4->A1.4.K,
#   A1.4->A2.4.V,
#   A2.4->A3.4.Q,
#   A3.4->Resid End],
#  [Resid Start->A0.1.V,
#   A0.1->A1.2.Q,
#   A1.2->A2.7.V,
#   A2.7->A3.2.Q,
#   A3.2->Resid End],
#  [Resid Start->A0.7.Q,
#   A0.7->A1.2.K,
#   A1.2->A2.1.V,
#   A2.1->A3.4.Q,
#   A3.4->Resid End],
#  [Resid Start->A0.4.Q, A0.4->A2.5.Q, A2.5->A3.7.K, A3.7->Resid End],
#  [Resid Start->A0.0.V,
#   A0.0->A1.6.K,
#   A1.6->A2.6.V,
#   A2.6->A3.1.V,
#   A3.1->Resid End],
#  [Resid Start->A0.3.K,
#   A0.3->A1.4.K,
#   A1.4->A2.7.K,
#   A2.7->A3.7.Q,
#   A3.7->Resid End],
#  [Resid Start->A1.6.Q, A1.6->A2.2.V, A2.2->A3.3.Q, A3.3->Resid End],
#  [Resid Start->A0.0.Q,
#   A0.0->A1.7.Q,
#   A1.7->A2.5.Q,
#   A2.5->A3.4.Q,
#   A3.4->Resid End],
#  [Resid Start->A0.7.K,
#   A0.7->A1.1.V,
#   A1.1->A2.3.Q,
#   A2.3->A3.2.Q,
#   A3.2->Resid End],
#  [Resid Start->A0.1.V,
#   A0.1->A1.1.Q,
#   A1.1->A2.5.V,
#   A2.5->A3.3.K,
#   A3.3->Resid End],
#  [Resid Start->A0.5.K,
#   A0.5->A1.2.V,
#   A1.2->A2.7.Q,
#   A2.7->A3.2.V,
#   A3.2->Resid End],
#  [Resid Start->A0.2.Q,
#   A0.2->A1.5.Q,
#   A1.5->A2.5.Q,
#   A2.5->A3.2.Q,
#   A3.2->Resid End],
#  [Resid Start->A0.0.V,
#   A0.0->A1.6.Q,
#   A1.6->A2.5.V,
#   A2.5->A3.2.K,
#   A3.2->Resid End],
#  [Resid Start->A0.1.V,
#   A0.1->A1.4.V,
#   A1.4->A2.0.K,
#   A2.0->A3.5.Q,
#   A3.5->Resid End],
#  [Resid Start->A0.5.V,
#   A0.5->A1.0.V,
#   A1.0->A2.6.K,
#   A2.6->A3.7.V,
#   A3.7->Resid End],
#  [Resid Start->A0.0.V,
#   A0.0->A1.5.V,
#   A1.5->A2.6.V,
#   A2.6->A3.5.Q,
#   A3.5->Resid End],
#  [Resid Start->A0.2.K,
#   A0.2->A1.3.Q,
#   A1.3->A2.3.Q,
#   A2.3->A3.1.K,
#   A3.1->Resid End],
#  [Resid Start->A0.4.V, A0.4->A2.6.Q, A2.6->A3.4.K, A3.4->Resid End],
#  [Resid Start->A0.4.Q,
#   A0.4->A1.6.K,
#   A1.6->A2.1.V,
#   A2.1->A3.7.V,
#   A3.7->Resid End],
#  [Resid Start->A0.7.V,
#   A0.7->A1.1.K,
#   A1.1->A2.1.V,
#   A2.1->A3.4.Q,
#   A3.4->Resid End],
#  [Resid Start->A0.3.K,
#   A0.3->A1.7.V,
#   A1.7->A2.0.K,
#   A2.0->A3.3.Q,
#   A3.3->Resid End],
#  [Resid Start->A0.5.V,
#   A0.5->A1.1.V,
#   A1.1->A2.2.V,
#   A2.2->A3.5.V,
#   A3.5->Resid End],
#  [Resid Start->A0.7.Q,
#   A0.7->A1.3.Q,
#   A1.3->A2.3.V,
#   A2.3->A3.7.K,
#   A3.7->Resid End],
#  [Resid Start->A0.5.Q,
#   A0.5->A1.6.Q,
#   A1.6->A2.0.V,
#   A2.0->A3.4.V,
#   A3.4->Resid End],
#  [Resid Start->A0.3.V,
#   A0.3->A1.5.K,
#   A1.5->A2.3.V,
#   A2.3->A3.1.V,
#   A3.1->Resid End],
#  [Resid Start->A0.2.K,
#   A0.2->A1.0.Q,
#   A1.0->A2.0.Q,
#   A2.0->A3.4.Q,
#   A3.4->Resid End],
#  [Resid Start->A0.6.K,
#   A0.6->A1.0.Q,
#   A1.0->A2.1.Q,
#   A2.1->A3.3.K,
#   A3.3->Resid End],
#  [Resid Start->A0.3.V,
#   A0.3->A1.7.Q,
#   A1.7->A2.2.K,
#   A2.2->A3.3.K,
#   A3.3->Resid End],
#  [Resid Start->A0.4.Q,
#   A0.4->A1.6.K,
#   A1.6->A2.5.K,
#   A2.5->A3.1.K,
#   A3.1->Resid End],
#  [Resid Start->A0.2.K,
#   A0.2->A1.5.K,
#   A1.5->A2.2.K,
#   A2.2->A3.5.K,
#   A3.5->Resid End],
#  [Resid Start->A0.7.K,
#   A0.7->A1.1.Q,
#   A1.1->A2.0.V,
#   A2.0->A3.5.K,
#   A3.5->Resid End],
#  [Resid Start->A0.4.V,
#   A0.4->A1.4.K,
#   A1.4->A2.0.Q,
#   A2.0->A3.7.K,
#   A3.7->Resid End],
#  [Resid Start->A0.2.Q,
#   A0.2->A1.1.V,
#   A1.1->A2.2.K,
#   A2.2->A3.1.K,
#   A3.1->Resid End],
#  [Resid Start->A0.1.Q,
#   A0.1->A1.0.Q,
#   A1.0->A2.1.K,
#   A2.1->A3.3.Q,
#   A3.3->Resid End],
#  [Resid Start->A0.1.Q,
#   A0.1->A1.5.Q,
#   A1.5->A2.5.K,
#   A2.5->A3.3.V,
#   A3.3->Resid End],
#  [Resid Start->A0.0.V,
#   A0.0->A1.2.K,
#   A1.2->A2.7.K,
#   A2.7->A3.4.V,
#   A3.4->Resid End],
#  [Resid Start->A0.6.V,
#   A0.6->A1.7.V,
#   A1.7->A2.2.V,
#   A2.2->A3.2.Q,
#   A3.2->Resid End],
#  [Resid Start->A0.5.Q, A0.5->A2.0.Q, A2.0->A3.1.V, A3.1->Resid End],
#  [Resid Start->A0.7.Q,
#   A0.7->A1.0.K,
#   A1.0->A2.1.V,
#   A2.1->A3.1.Q,
#   A3.1->Resid End],
#  [Resid Start->A0.1.Q,
#   A0.1->A1.1.K,
#   A1.1->A2.7.K,
#   A2.7->A3.2.Q,
#   A3.2->Resid End],
#  [Resid Start->A0.1.Q,
#   A0.1->A1.2.K,
#   A1.2->A2.3.V,
#   A2.3->A3.2.V,
#   A3.2->Resid End],
#  [Resid Start->A0.7.Q,
#   A0.7->A1.5.V,
#   A1.5->A2.5.K,
#   A2.5->A3.2.Q,
#   A3.2->Resid End],
#  [Resid Start->A0.2.K,
#   A0.2->A1.5.V,
#   A1.5->A2.2.Q,
#   A2.2->A3.2.Q,
#   A3.2->Resid End],
#  [Resid Start->A0.7.Q,
#   A0.7->A1.4.V,
#   A1.4->A2.1.K,
#   A2.1->A3.1.V,
#   A3.1->Resid End],
#  [Resid Start->A0.5.V,
#   A0.5->A1.6.K,
#   A1.6->A2.3.K,
#   A2.3->A3.5.V,
#   A3.5->Resid End],
#  [Resid Start->A0.2.K,
#   A0.2->A1.7.K,
#   A1.7->A2.7.K,
#   A2.7->A3.5.V,
#   A3.5->Resid End],
#  [Resid Start->A0.4.Q,
#   A0.4->A1.6.K,
#   A1.6->A2.2.K,
#   A2.2->A3.3.Q,
#   A3.3->Resid End],
#  [Resid Start->A0.1.V,
#   A0.1->A1.3.K,
#   A1.3->A2.6.K,
#   A2.6->A3.5.V,
#   A3.5->Resid End],
#  [Resid Start->A0.5.Q,
#   A0.5->A1.7.K,
#   A1.7->A2.5.V,
#   A2.5->A3.2.Q,
#   A3.2->Resid End],
#  [Resid Start->A0.4.K,
#   A0.4->A1.6.V,
#   A1.6->A2.3.Q,
#   A2.3->A3.2.V,
#   A3.2->Resid End],
#  [Resid Start->A0.7.K,
#   A0.7->A1.7.Q,
#   A1.7->A2.1.K,
#   A2.1->A3.7.K,
#   A3.7->Resid End],
#  [Resid Start->A0.6.K,
#   A0.6->A1.2.K,
#   A1.2->A2.7.K,
#   A2.7->A3.3.K,
#   A3.3->Resid End],
#  [Resid Start->A0.4.V,
#   A0.4->A1.1.K,
#   A1.1->A2.5.Q,
#   A2.5->A3.4.V,
#   A3.4->Resid End],
#  [Resid Start->A0.5.Q,
#   A0.5->A1.0.Q,
#   A1.0->A2.6.K,
#   A2.6->A3.7.V,
#   A3.7->Resid End],
#  [Resid Start->A0.4.Q, A0.4->A2.3.V, A2.3->A3.3.Q, A3.3->Resid End],
#  [Resid Start->A0.4.V,
#   A0.4->A1.4.V,
#   A1.4->A2.3.Q,
#   A2.3->A3.3.Q,
#   A3.3->Resid End],
#  [Resid Start->A0.4.V,
#   A0.4->A1.5.K,
#   A1.5->A2.0.Q,
#   A2.0->A3.4.K,
#   A3.4->Resid End],
#  [Resid Start->A0.2.Q,
#   A0.2->A1.6.V,
#   A1.6->A2.5.Q,
#   A2.5->A3.3.V,
#   A3.3->Resid End],
#  [Resid Start->A0.3.Q,
#   A0.3->A1.2.K,
#   A1.2->A2.4.K,
#   A2.4->A3.5.Q,
#   A3.5->Resid End],
#  [Resid Start->A0.2.V, A0.2->A1.0.K, A1.0->A3.1.K, A3.1->Resid End],
#  [Resid Start->A0.6.V,
#   A0.6->A1.0.K,
#   A1.0->A2.7.K,
#   A2.7->A3.5.K,
#   A3.5->Resid End],
#  [Resid Start->A0.3.K,
#   A0.3->A1.2.V,
#   A1.2->A2.6.Q,
#   A2.6->A3.4.V,
#   A3.4->Resid End],
#  [Resid Start->A0.2.K,
#   A0.2->A1.0.V,
#   A1.0->A2.6.V,
#   A2.6->A3.7.K,
#   A3.7->Resid End],
#  [Resid Start->A0.2.Q,
#   A0.2->A1.1.Q,
#   A1.1->A2.0.Q,
#   A2.0->A3.7.Q,
#   A3.7->Resid End],
#  [Resid Start->A0.0.V,
#   A0.0->A1.2.K,
#   A1.2->A2.4.K,
#   A2.4->A3.2.K,
#   A3.2->Resid End],
#  [Resid Start->A0.2.Q,
#   A0.2->A1.3.V,
#   A1.3->A2.4.V,
#   A2.4->A3.1.V,
#   A3.1->Resid End],
#  [Resid Start->A0.0.K,
#   A0.0->A1.6.Q,
#   A1.6->A2.4.V,
#   A2.4->A3.2.V,
#   A3.2->Resid End],
#  [Resid Start->A0.4.K,
#   A0.4->A1.2.K,
#   A1.2->A2.6.Q,
#   A2.6->A3.3.V,
#   A3.3->Resid End],
#  [Resid Start->A0.1.K,
#   A0.1->A1.6.V,
#   A1.6->A2.4.Q,
#   A2.4->A3.7.Q,
#   A3.7->Resid End],
#  [Resid Start->A0.5.V,
#   A0.5->A1.6.V,
#   A1.6->A2.7.V,
#   A2.7->A3.2.K,
#   A3.2->Resid End],
#  [Resid Start->A0.0.K,
#   A0.0->A1.5.Q,
#   A1.5->A2.3.K,
#   A2.3->A3.5.V,
#   A3.5->Resid End],
#  [Resid Start->A0.3.Q,
#   A0.3->A1.3.V,
#   A1.3->A2.4.V,
#   A2.4->A3.5.Q,
#   A3.5->Resid End],
#  [Resid Start->A0.4.K,
#   A0.4->A1.4.V,
#   A1.4->A2.4.Q,
#   A2.4->A3.1.K,
#   A3.1->Resid End],
#  [Resid Start->A0.5.K,
#   A0.5->A1.5.V,
#   A1.5->A2.6.K,
#   A2.6->A3.3.K,
#   A3.3->Resid End],
#  [Resid Start->A0.3.K,
#   A0.3->A1.4.V,
#   A1.4->A2.1.Q,
#   A2.1->A3.2.K,
#   A3.2->Resid End],
#  [Resid Start->A0.5.V,
#   A0.5->A1.0.K,
#   A1.0->A2.7.Q,
#   A2.7->A3.4.K,
#   A3.4->Resid End],
#  [Resid Start->A0.4.V,
#   A0.4->A1.1.Q,
#   A1.1->A2.4.V,
#   A2.4->A3.7.K,
#   A3.7->Resid End],
#  [Resid Start->A1.3.K, A1.3->A2.6.V, A2.6->A3.3.V, A3.3->Resid End],
#  [Resid Start->A0.6.K,
#   A0.6->A1.7.K,
#   A1.7->A2.5.V,
#   A2.5->A3.4.Q,
#   A3.4->Resid End],
#  [Resid Start->A0.5.K,
#   A0.5->A1.5.Q,
#   A1.5->A2.4.V,
#   A2.4->A3.5.Q,
#   A3.5->Resid End],
#  [Resid Start->A0.0.V,
#   A0.0->A1.6.V,
#   A1.6->A2.0.K,
#   A2.0->A3.5.K,
#   A3.5->Resid End],
#  [Resid Start->A0.0.V,
#   A0.0->A1.1.K,
#   A1.1->A2.5.Q,
#   A2.5->A3.4.Q,
#   A3.4->Resid End],
#  [Resid Start->A0.5.K,
#   A0.5->A1.2.V,
#   A1.2->A2.4.K,
#   A2.4->A3.5.K,
#   A3.5->Resid End],
#  [Resid Start->A0.7.K,
#   A0.7->A1.5.V,
#   A1.5->A2.2.Q,
#   A2.2->A3.7.Q,
#   A3.7->Resid End],
#  [Resid Start->A0.6.K,
#   A0.6->A1.0.Q,
#   A1.0->A2.7.Q,
#   A2.7->A3.5.K,
#   A3.5->Resid End],
#  [Resid Start->A0.7.Q,
#   A0.7->A1.3.V,
#   A1.3->A2.0.K,
#   A2.0->A3.4.Q,
#   A3.4->Resid End],
#  [Resid Start->A0.1.K,
#   A0.1->A1.2.V,
#   A1.2->A2.0.Q,
#   A2.0->A3.3.V,
#   A3.3->Resid End],
#  [Resid Start->A0.0.K,
#   A0.0->A1.5.V,
#   A1.5->A2.0.Q,
#   A2.0->A3.5.V,
#   A3.5->Resid End],
#  [Resid Start->A0.6.K,
#   A0.6->A1.6.K,
#   A1.6->A2.3.V,
#   A2.3->A3.1.Q,
#   A3.1->Resid End],
#  [Resid Start->A0.6.K,
#   A0.6->A1.0.Q,
#   A1.0->A2.5.K,
#   A2.5->A3.5.Q,
#   A3.5->Resid End],
#  [Resid Start->A0.0.K,
#   A0.0->A1.3.K,
#   A1.3->A2.7.K,
#   A2.7->A3.5.V,
#   A3.5->Resid End],
#  [Resid Start->A0.0.Q,
#   A0.0->A1.6.Q,
#   A1.6->A2.1.V,
#   A2.1->A3.3.K,
#   A3.3->Resid End],
#  [Resid Start->A1.3.K, A1.3->A2.6.K, A2.6->A3.3.K, A3.3->Resid End],
#  [Resid Start->A0.5.V,
#   A0.5->A1.6.Q,
#   A1.6->A2.7.Q,
#   A2.7->A3.4.V,
#   A3.4->Resid End],
#  [Resid Start->A0.0.V,
#   A0.0->A1.1.Q,
#   A1.1->A2.3.K,
#   A2.3->A3.1.Q,
#   A3.1->Resid End],
#  [Resid Start->A0.7.Q,
#   A0.7->A1.4.K,
#   A1.4->A2.6.Q,
#   A2.6->A3.1.V,
#   A3.1->Resid End],
#  [Resid Start->A0.0.K,
#   A0.0->A1.5.Q,
#   A1.5->A2.3.V,
#   A2.3->A3.3.V,
#   A3.3->Resid End],
#  [Resid Start->A0.5.V,
#   A0.5->A1.4.Q,
#   A1.4->A2.2.Q,
#   A2.2->A3.7.K,
#   A3.7->Resid End],
#  [Resid Start->A0.6.V,
#   A0.6->A1.3.K,
#   A1.3->A2.0.Q,
#   A2.0->A3.4.K,
#   A3.4->Resid End],
#  [Resid Start->A0.3.V,
#   A0.3->A1.6.K,
#   A1.6->A2.6.K,
#   A2.6->A3.7.Q,
#   A3.7->Resid End],
#  [Resid Start->A0.6.V,
#   A0.6->A1.7.V,
#   A1.7->A2.2.K,
#   A2.2->A3.7.V,
#   A3.7->Resid End],
#  [Resid Start->A0.5.Q,
#   A0.5->A1.3.V,
#   A1.3->A2.2.Q,
#   A2.2->A3.4.K,
#   A3.4->Resid End],
#  [Resid Start->A0.2.Q,
#   A0.2->A1.0.Q,
#   A1.0->A2.4.Q,
#   A2.4->A3.1.Q,
#   A3.1->Resid End],
#  [Resid Start->A0.0.V,
#   A0.0->A1.1.K,
#   A1.1->A2.1.K,
#   A2.1->A3.5.K,
#   A3.5->Resid End],
#  [Resid Start->A0.6.Q,
#   A0.6->A1.6.V,
#   A1.6->A2.7.Q,
#   A2.7->A3.3.V,
#   A3.3->Resid End],
#  [Resid Start->A0.3.Q,
#   A0.3->A1.7.Q,
#   A1.7->A2.6.K,
#   A2.6->A3.1.Q,
#   A3.1->Resid End],
#  [Resid Start->A0.3.K,
#   A0.3->A1.3.K,
#   A1.3->A2.6.V,
#   A2.6->A3.5.V,
#   A3.5->Resid End],
#  [Resid Start->A0.6.K,
#   A0.6->A1.7.Q,
#   A1.7->A2.0.Q,
#   A2.0->A3.4.K,
#   A3.4->Resid End],
#  [Resid Start->A0.7.Q,
#   A0.7->A1.2.Q,
#   A1.2->A2.7.Q,
#   A2.7->A3.4.V,
#   A3.4->Resid End],
#  [Resid Start->A0.3.K,
#   A0.3->A1.5.Q,
#   A1.5->A2.3.K,
#   A2.3->A3.7.K,
#   A3.7->Resid End],
#  [Resid Start->A0.5.K,
#   A0.5->A1.5.K,
#   A1.5->A2.6.Q,
#   A2.6->A3.4.K,
#   A3.4->Resid End],
#  [Resid Start->A0.3.K,
#   A0.3->A1.1.K,
#   A1.1->A2.1.V,
#   A2.1->A3.4.V,
#   A3.4->Resid End],
#  [Resid Start->A0.7.K,
#   A0.7->A1.2.Q,
#   A1.2->A2.4.V,
#   A2.4->A3.4.V,
#   A3.4->Resid End],
#  [Resid Start->A0.0.K,
#   A0.0->A1.3.V,
#   A1.3->A2.3.K,
#   A2.3->A3.3.K,
#   A3.3->Resid End],
#  [Resid Start->A0.5.K, A0.5->A2.0.V, A2.0->A3.5.Q, A3.5->Resid End],
#  [Resid Start->A0.6.Q,
#   A0.6->A1.7.K,
#   A1.7->A2.7.V,
#   A2.7->A3.5.K,
#   A3.5->Resid End],
#  [Resid Start->A0.2.V,
#   A0.2->A1.5.V,
#   A1.5->A2.3.V,
#   A2.3->A3.1.K,
#   A3.1->Resid End],
#  [Resid Start->A0.1.V,
#   A0.1->A1.4.Q,
#   A1.4->A2.5.Q,
#   A2.5->A3.4.V,
#   A3.4->Resid End],
#  [Resid Start->A0.3.V,
#   A0.3->A1.5.V,
#   A1.5->A2.7.Q,
#   A2.7->A3.2.Q,
#   A3.2->Resid End],
#  [Resid Start->A0.0.V,
#   A0.0->A1.1.K,
#   A1.1->A2.6.K,
#   A2.6->A3.7.V,
#   A3.7->Resid End],
#  [Resid Start->A0.7.K,
#   A0.7->A1.3.K,
#   A1.3->A2.0.K,
#   A2.0->A3.2.V,
#   A3.2->Resid End],
#  [Resid Start->A0.5.V,
#   A0.5->A1.1.Q,
#   A1.1->A2.0.Q,
#   A2.0->A3.5.K,
#   A3.5->Resid End],
#  [Resid Start->A0.4.V,
#   A0.4->A1.6.Q,
#   A1.6->A2.5.V,
#   A2.5->A3.3.Q,
#   A3.3->Resid End],
#  [Resid Start->A0.4.V,
#   A0.4->A1.2.Q,
#   A1.2->A2.5.K,
#   A2.5->A3.7.K,
#   A3.7->Resid End],
#  [Resid Start->A0.3.K, A0.3->A1.5.Q, A1.5->A3.7.Q, A3.7->Resid End],
#  [Resid Start->A0.3.K,
#   A0.3->A1.7.Q,
#   A1.7->A2.2.V,
#   A2.2->A3.3.V,
#   A3.3->Resid End],
#  [Resid Start->A0.0.V,
#   A0.0->A1.4.K,
#   A1.4->A2.4.K,
#   A2.4->A3.7.K,
#   A3.7->Resid End],
#  [Resid Start->A0.6.K,
#   A0.6->A1.5.Q,
#   A1.5->A2.3.Q,
#   A2.3->A3.1.Q,
#   A3.1->Resid End],
#  [Resid Start->A0.5.K,
#   A0.5->A1.6.V,
#   A1.6->A2.6.K,
#   A2.6->A3.7.K,
#   A3.7->Resid End],
#  [Resid Start->A0.1.V,
#   A0.1->A1.7.V,
#   A1.7->A2.3.Q,
#   A2.3->A3.4.Q,
#   A3.4->Resid End],
#  [Resid Start->A0.2.K,
#   A0.2->A1.6.K,
#   A1.6->A2.6.Q,
#   A2.6->A3.4.V,
#   A3.4->Resid End],
#  [Resid Start->A0.3.V, A0.3->A2.4.V, A2.4->A3.4.K, A3.4->Resid End],
#  [Resid Start->A0.0.K,
#   A0.0->A1.3.V,
#   A1.3->A2.7.K,
#   A2.7->A3.2.V,
#   A3.2->Resid End],
#  [Resid Start->A0.6.K,
#   A0.6->A1.2.V,
#   A1.2->A2.0.K,
#   A2.0->A3.3.K,
#   A3.3->Resid End],
#  [Resid Start->A0.5.Q,
#   A0.5->A1.4.K,
#   A1.4->A2.2.K,
#   A2.2->A3.2.V,
#   A3.2->Resid End],
#  [Resid Start->A0.2.V,
#   A0.2->A1.6.Q,
#   A1.6->A2.6.V,
#   A2.6->A3.5.V,
#   A3.5->Resid End],
#  [Resid Start->A0.5.Q,
#   A0.5->A1.4.Q,
#   A1.4->A2.2.K,
#   A2.2->A3.3.Q,
#   A3.3->Resid End],
#  [Resid Start->A0.0.V,
#   A0.0->A1.5.K,
#   A1.5->A2.5.K,
#   A2.5->A3.4.V,
#   A3.4->Resid End],
#  [Resid Start->A0.4.Q,
#   A0.4->A1.5.V,
#   A1.5->A2.1.K,
#   A2.1->A3.3.Q,
#   A3.3->Resid End],
#  [Resid Start->A0.2.Q, A0.2->A2.1.V, A2.1->A3.7.V, A3.7->Resid End],
#  [Resid Start->A0.5.K,
#   A0.5->A1.2.V,
#   A1.2->A2.5.Q,
#   A2.5->A3.1.V,
#   A3.1->Resid End],
#  [Resid Start->A0.6.V,
#   A0.6->A1.7.V,
#   A1.7->A2.5.Q,
#   A2.5->A3.4.V,
#   A3.4->Resid End],
#  [Resid Start->A0.5.V,
#   A0.5->A1.0.Q,
#   A1.0->A2.5.V,
#   A2.5->A3.5.K,
#   A3.5->Resid End],
#  [Resid Start->A0.1.K,
#   A0.1->A1.7.V,
#   A1.7->A2.6.Q,
#   A2.6->A3.1.Q,
#   A3.1->Resid End],
#  [Resid Start->A1.2.Q, A1.2->A2.4.Q, A2.4->A3.2.Q, A3.2->Resid End],
#  [Resid Start->A0.2.V,
#   A0.2->A1.7.V,
#   A1.7->A2.4.Q,
#   A2.4->A3.3.V,
#   A3.3->Resid End],
#  [Resid Start->A0.0.Q,
#   A0.0->A1.3.K,
#   A1.3->A2.6.Q,
#   A2.6->A3.4.K,
#   A3.4->Resid End],
#  [Resid Start->A0.5.Q,
#   A0.5->A1.7.K,
#   A1.7->A2.2.V,
#   A2.2->A3.3.Q,
#   A3.3->Resid End],
#  [Resid Start->A0.1.Q,
#   A0.1->A1.1.Q,
#   A1.1->A2.7.V,
#   A2.7->A3.2.V,
#   A3.2->Resid End],
#  [Resid Start->A0.5.V,
#   A0.5->A1.7.Q,
#   A1.7->A2.0.K,
#   A2.0->A3.7.V,
#   A3.7->Resid End],
#  [Resid Start->A0.0.K,
#   A0.0->A1.3.Q,
#   A1.3->A2.3.Q,
#   A2.3->A3.3.V,
#   A3.3->Resid End],
#  [Resid Start->A0.4.V,
#   A0.4->A1.0.K,
#   A1.0->A2.3.Q,
#   A2.3->A3.3.Q,
#   A3.3->Resid End],
#  [Resid Start->A0.0.Q,
#   A0.0->A1.1.Q,
#   A1.1->A2.1.Q,
#   A2.1->A3.5.Q,
#   A3.5->Resid End],
#  [Resid Start->A0.1.V,
#   A0.1->A1.7.K,
#   A1.7->A2.2.Q,
#   A2.2->A3.2.K,
#   A3.2->Resid End],
#  [Resid Start->A0.3.Q,
#   A0.3->A1.2.Q,
#   A1.2->A2.6.V,
#   A2.6->A3.2.Q,
#   A3.2->Resid End],
#  [Resid Start->A0.1.K, A0.1->A2.6.K, A2.6->A3.1.Q, A3.1->Resid End],
#  [Resid Start->A0.4.Q,
#   A0.4->A1.7.Q,
#   A1.7->A2.5.Q,
#   A2.5->A3.7.V,
#   A3.7->Resid End],
#  [Resid Start->A0.4.V,
#   A0.4->A1.2.K,
#   A1.2->A2.5.K,
#   A2.5->A3.7.K,
#   A3.7->Resid End],
#  [Resid Start->A0.4.K,
#   A0.4->A1.2.V,
#   A1.2->A2.7.K,
#   A2.7->A3.5.V,
#   A3.5->Resid End],
#  [Resid Start->A0.5.V,
#   A0.5->A1.0.V,
#   A1.0->A2.7.K,
#   A2.7->A3.5.K,
#   A3.5->Resid End],
#  [Resid Start->A0.2.K,
#   A0.2->A1.2.K,
#   A1.2->A2.1.K,
#   A2.1->A3.4.Q,
#   A3.4->Resid End],
#  [Resid Start->A0.3.Q, A0.3->A2.1.Q, A2.1->A3.4.V, A3.4->Resid End],
#  [Resid Start->A0.2.Q,
#   A0.2->A1.6.K,
#   A1.6->A2.5.K,
#   A2.5->A3.7.Q,
#   A3.7->Resid End],
#  [Resid Start->A0.3.V,
#   A0.3->A1.5.V,
#   A1.5->A2.0.V,
#   A2.0->A3.1.Q,
#   A3.1->Resid End],
#  [Resid Start->A0.0.V,
#   A0.0->A1.3.V,
#   A1.3->A2.1.K,
#   A2.1->A3.1.V,
#   A3.1->Resid End],
#  [Resid Start->A1.0.V, A1.0->A2.0.K, A2.0->A3.3.V, A3.3->Resid End],
#  [Resid Start->A0.6.K,
#   A0.6->A1.4.V,
#   A1.4->A2.6.V,
#   A2.6->A3.2.K,
#   A3.2->Resid End],
#  [Resid Start->A0.4.V,
#   A0.4->A1.6.Q,
#   A1.6->A2.2.Q,
#   A2.2->A3.1.Q,
#   A3.1->Resid End],
#  [Resid Start->A0.0.K,
#   A0.0->A1.3.K,
#   A1.3->A2.5.V,
#   A2.5->A3.1.Q,
#   A3.1->Resid End],
#  [Resid Start->A0.6.K,
#   A0.6->A1.3.V,
#   A1.3->A2.7.Q,
#   A2.7->A3.1.K,
#   A3.1->Resid End],
#  [Resid Start->A0.4.K,
#   A0.4->A1.4.V,
#   A1.4->A2.6.V,
#   A2.6->A3.1.Q,
#   A3.1->Resid End],
#  [Resid Start->A0.0.K,
#   A0.0->A1.4.V,
#   A1.4->A2.7.V,
#   A2.7->A3.2.K,
#   A3.2->Resid End],
#  [Resid Start->A0.7.K,
#   A0.7->A1.2.V,
#   A1.2->A2.3.V,
#   A2.3->A3.4.V,
#   A3.4->Resid End],
#  [Resid Start->A0.3.Q,
#   A0.3->A1.4.V,
#   A1.4->A2.2.V,
#   A2.2->A3.5.K,
#   A3.5->Resid End],
#  [Resid Start->A0.5.Q,
#   A0.5->A1.2.K,
#   A1.2->A2.6.Q,
#   A2.6->A3.2.K,
#   A3.2->Resid End],
#  [Resid Start->A0.0.Q,
#   A0.0->A1.2.V,
#   A1.2->A2.6.Q,
#   A2.6->A3.1.V,
#   A3.1->Resid End],
#  [Resid Start->A0.0.K, A0.0->A1.1.K, A1.1->A3.5.K, A3.5->Resid End],
#  [Resid Start->A0.3.K,
#   A0.3->A1.3.V,
#   A1.3->A2.4.K,
#   A2.4->A3.5.Q,
#   A3.5->Resid End],
#  [Resid Start->A0.2.K,
#   A0.2->A1.1.V,
#   A1.1->A2.0.K,
#   A2.0->A3.2.K,
#   A3.2->Resid End],
#  [Resid Start->A0.2.V,
#   A0.2->A1.4.Q,
#   A1.4->A2.4.V,
#   A2.4->A3.4.Q,
#   A3.4->Resid End],
#  [Resid Start->A0.6.V,
#   A0.6->A1.2.V,
#   A1.2->A2.4.K,
#   A2.4->A3.7.K,
#   A3.7->Resid End],
#  [Resid Start->A0.4.V,
#   A0.4->A1.0.K,
#   A1.0->A2.3.K,
#   A2.3->A3.3.K,
#   A3.3->Resid End],
#  [Resid Start->A0.2.K,
#   A0.2->A1.7.V,
#   A1.7->A2.4.K,
#   A2.4->A3.2.K,
#   A3.2->Resid End],
#  [Resid Start->A0.1.V,
#   A0.1->A1.3.Q,
#   A1.3->A2.0.K,
#   A2.0->A3.2.K,
#   A3.2->Resid End],
#  [Resid Start->A0.6.K,
#   A0.6->A1.2.K,
#   A1.2->A2.1.Q,
#   A2.1->A3.3.K,
#   A3.3->Resid End],
#  [Resid Start->A0.7.Q,
#   A0.7->A1.7.K,
#   A1.7->A2.5.V,
#   A2.5->A3.3.Q,
#   A3.3->Resid End],
#  [Resid Start->A0.1.Q,
#   A0.1->A1.1.V,
#   A1.1->A2.7.Q,
#   A2.7->A3.1.Q,
#   A3.1->Resid End],
#  [Resid Start->A0.3.K,
#   A0.3->A1.5.V,
#   A1.5->A2.3.V,
#   A2.3->A3.7.V,
#   A3.7->Resid End],
#  [Resid Start->A0.0.Q,
#   A0.0->A1.3.Q,
#   A1.3->A2.1.Q,
#   A2.1->A3.7.Q,
#   A3.7->Resid End],
#  [Resid Start->A0.6.K,
#   A0.6->A1.6.V,
#   A1.6->A2.0.K,
#   A2.0->A3.2.Q,
#   A3.2->Resid End],
#  [Resid Start->A0.5.V,
#   A0.5->A1.5.Q,
#   A1.5->A2.7.K,
#   A2.7->A3.4.V,
#   A3.4->Resid End],
#  [Resid Start->A1.6.V, A1.6->A2.6.K, A2.6->A3.3.V, A3.3->Resid End],
#  [Resid Start->A0.7.V,
#   A0.7->A1.7.V,
#   A1.7->A2.7.V,
#   A2.7->A3.7.V,
#   A3.7->Resid End],
#  [Resid Start->A0.5.K,
#   A0.5->A1.3.K,
#   A1.3->A2.2.K,
#   A2.2->A3.1.K,
#   A3.1->Resid End],
#  [Resid Start->A0.5.V,
#   A0.5->A1.6.Q,
#   A1.6->A2.5.V,
#   A2.5->A3.5.Q,
#   A3.5->Resid End],
#  [Resid Start->A1.5.V, A1.5->A3.5.K, A3.5->Resid End],
#  [Resid Start->A0.5.Q,
#   A0.5->A1.0.Q,
#   A1.0->A2.1.Q,
#   A2.1->A3.4.V,
#   A3.4->Resid End],
#  [Resid Start->A0.7.V,
#   A0.7->A1.7.V,
#   A1.7->A2.6.Q,
#   A2.6->A3.7.V,
#   A3.7->Resid End],
#  [Resid Start->A0.6.V,
#   A0.6->A1.4.Q,
#   A1.4->A2.4.Q,
#   A2.4->A3.7.Q,
#   A3.7->Resid End],
#  [Resid Start->A0.0.Q,
#   A0.0->A1.2.V,
#   A1.2->A2.2.K,
#   A2.2->A3.2.K,
#   A3.2->Resid End],
#  [Resid Start->A0.0.K,
#   A0.0->A1.1.Q,
#   A1.1->A2.6.V,
#   A2.6->A3.2.Q,
#   A3.2->Resid End],
#  [Resid Start->A1.1.Q, A1.1->A2.7.Q, A2.7->A3.7.Q, A3.7->Resid End],
#  [Resid Start->A0.4.Q,
#   A0.4->A1.1.V,
#   A1.1->A2.1.Q,
#   A2.1->A3.4.V,
#   A3.4->Resid End],
#  [Resid Start->A0.2.V,
#   A0.2->A1.5.V,
#   A1.5->A2.2.V,
#   A2.2->A3.3.K,
#   A3.3->Resid End],
#  [Resid Start->A0.5.K,
#   A0.5->A1.2.K,
#   A1.2->A2.3.V,
#   A2.3->A3.7.Q,
#   A3.7->Resid End],
#  [Resid Start->A1.7.V, A1.7->A2.3.V, A2.3->A3.2.K, A3.2->Resid End],
#  [Resid Start->A0.3.V,
#   A0.3->A1.4.V,
#   A1.4->A2.4.V,
#   A2.4->A3.1.K,
#   A3.1->Resid End],
#  [Resid Start->A1.2.K, A1.2->A2.6.K, A2.6->A3.5.K, A3.5->Resid End],
#  [Resid Start->A0.4.Q,
#   A0.4->A1.2.Q,
#   A1.2->A2.7.K,
#   A2.7->A3.1.K,
#   A3.1->Resid End],
#  [Resid Start->A0.6.V,
#   A0.6->A1.0.V,
#   A1.0->A2.0.V,
#   A2.0->A3.1.Q,
#   A3.1->Resid End],
#  [Resid Start->A0.5.V,
#   A0.5->A1.2.K,
#   A1.2->A2.7.Q,
#   A2.7->A3.7.V,
#   A3.7->Resid End],
#  [Resid Start->A0.4.V,
#   A0.4->A1.1.Q,
#   A1.1->A2.3.Q,
#   A2.3->A3.4.V,
#   A3.4->Resid End],
#  [Resid Start->A0.3.V,
#   A0.3->A1.0.V,
#   A1.0->A2.3.V,
#   A2.3->A3.7.K,
#   A3.7->Resid End],
#  [Resid Start->A0.5.Q, A0.5->A2.6.V, A2.6->A3.7.Q, A3.7->Resid End],
#  [Resid Start->A0.7.K,
#   A0.7->A1.3.Q,
#   A1.3->A2.1.V,
#   A2.1->A3.1.V,
#   A3.1->Resid End],
#  [Resid Start->A0.4.V,
#   A0.4->A1.5.Q,
#   A1.5->A2.7.K,
#   A2.7->A3.7.Q,
#   A3.7->Resid End],
#  [Resid Start->A0.3.K, A0.3->A1.5.K, A1.5->A3.7.V, A3.7->Resid End],
#  [Resid Start->A0.0.Q,
#   A0.0->A1.6.Q,
#   A1.6->A2.3.K,
#   A2.3->A3.3.K,
#   A3.3->Resid End],
#  [Resid Start->A0.5.K, A0.5->A2.0.Q, A2.0->A3.4.Q, A3.4->Resid End],
#  [Resid Start->A1.6.V, A1.6->A2.3.Q, A2.3->A3.4.K, A3.4->Resid End],
#  [Resid Start->A0.1.V,
#   A0.1->A1.0.Q,
#   A1.0->A2.1.Q,
#   A2.1->A3.1.K,
#   A3.1->Resid End],
#  [Resid Start->A0.5.V,
#   A0.5->A1.5.V,
#   A1.5->A2.6.V,
#   A2.6->A3.1.K,
#   A3.1->Resid End],
#  [Resid Start->A0.0.V,
#   A0.0->A1.5.Q,
#   A1.5->A2.6.Q,
#   A2.6->A3.7.Q,
#   A3.7->Resid End],
#  [Resid Start->A1.2.K, A1.2->A2.6.K, A2.6->A3.7.K, A3.7->Resid End],
#  [Resid Start->A0.7.K,
#   A0.7->A1.6.V,
#   A1.6->A2.2.K,
#   A2.2->A3.5.K,
#   A3.5->Resid End],
#  [Resid Start->A0.0.K,
#   A0.0->A1.3.Q,
#   A1.3->A2.0.K,
#   A2.0->A3.1.Q,
#   A3.1->Resid End],
#  [Resid Start->A0.6.K, A0.6->A2.4.K, A2.4->A3.3.K, A3.3->Resid End],
#  [Resid Start->A0.4.V,
#   A0.4->A1.4.K,
#   A1.4->A2.4.K,
#   A2.4->A3.7.Q,
#   A3.7->Resid End],
#  [Resid Start->A0.4.Q,
#   A0.4->A1.2.V,
#   A1.2->A2.3.K,
#   A2.3->A3.2.Q,
#   A3.2->Resid End],
#  [Resid Start->A1.4.V, A1.4->A2.6.K, A2.6->A3.1.V, A3.1->Resid End],
#  [Resid Start->A0.6.K, A0.6->A2.7.K, A2.7->A3.5.Q, A3.5->Resid End],
#  [Resid Start->A0.0.V,
#   A0.0->A1.5.V,
#   A1.5->A2.0.V,
#   A2.0->A3.2.V,
#   A3.2->Resid End],
#  [Resid Start->A0.5.K,
#   A0.5->A1.1.Q,
#   A1.1->A2.3.V,
#   A2.3->A3.2.V,
#   A3.2->Resid End],
#  [Resid Start->A0.7.K,
#   A0.7->A1.1.Q,
#   A1.1->A2.1.K,
#   A2.1->A3.7.V,
#   A3.7->Resid End],
#  [Resid Start->A0.4.K,
#   A0.4->A1.1.K,
#   A1.1->A2.5.K,
#   A2.5->A3.5.K,
#   A3.5->Resid End],
#  [Resid Start->A0.3.V,
#   A0.3->A1.6.K,
#   A1.6->A2.3.V,
#   A2.3->A3.4.K,
#   A3.4->Resid End],
#  [Resid Start->A0.7.Q,
#   A0.7->A1.5.V,
#   A1.5->A2.5.Q,
#   A2.5->A3.1.V,
#   A3.1->Resid End],
#  [Resid Start->A0.7.V,
#   A0.7->A1.6.Q,
#   A1.6->A2.6.Q,
#   A2.6->A3.3.V,
#   A3.3->Resid End],
#  [Resid Start->A0.6.Q,
#   A0.6->A1.7.Q,
#   A1.7->A2.2.V,
#   A2.2->A3.1.Q,
#   A3.1->Resid End],
#  [Resid Start->A0.2.V,
#   A0.2->A1.3.V,
#   A1.3->A2.4.K,
#   A2.4->A3.5.Q,
#   A3.5->Resid End],
#  [Resid Start->A0.0.Q,
#   A0.0->A1.3.Q,
#   A1.3->A2.2.V,
#   A2.2->A3.2.K,
#   A3.2->Resid End],
#  [Resid Start->A0.0.Q,
#   A0.0->A1.3.V,
#   A1.3->A2.6.Q,
#   A2.6->A3.2.Q,
#   A3.2->Resid End],
#  [Resid Start->A0.3.V,
#   A0.3->A1.2.Q,
#   A1.2->A2.7.Q,
#   A2.7->A3.7.V,
#   A3.7->Resid End],
#  [Resid Start->A0.5.Q,
#   A0.5->A1.3.Q,
#   A1.3->A2.5.Q,
#   A2.5->A3.4.Q,
#   A3.4->Resid End],
#  [Resid Start->A0.5.K,
#   A0.5->A1.2.Q,
#   A1.2->A2.5.V,
#   A2.5->A3.5.Q,
#   A3.5->Resid End],
#  [Resid Start->A0.6.Q,
#   A0.6->A1.2.Q,
#   A1.2->A2.4.Q,
#   A2.4->A3.1.Q,
#   A3.1->Resid End],
#  [Resid Start->A0.3.K,
#   A0.3->A1.5.V,
#   A1.5->A2.5.V,
#   A2.5->A3.3.V,
#   A3.3->Resid End],
#  [Resid Start->A1.1.Q, A1.1->A2.4.V, A2.4->A3.2.Q, A3.2->Resid End],
#  [Resid Start->A0.2.V,
#   A0.2->A1.0.Q,
#   A1.0->A2.7.V,
#   A2.7->A3.4.K,
#   A3.4->Resid End],
#  [Resid Start->A0.6.K,
#   A0.6->A1.5.Q,
#   A1.5->A2.7.Q,
#   A2.7->A3.5.K,
#   A3.5->Resid End],
#  [Resid Start->A0.2.Q,
#   A0.2->A1.3.Q,
#   A1.3->A2.4.Q,
#   A2.4->A3.3.K,
#   A3.3->Resid End],
#  [Resid Start->A0.6.V,
#   A0.6->A1.5.K,
#   A1.5->A2.3.V,
#   A2.3->A3.1.V,
#   A3.1->Resid End]]

# %% [markdown]
# # Circuit Sequence Graph

# %%
circ_graph = SeqGraph(task.true_edges, task.token_circuit, task.model.cfg.attn_only)

# %%
# check reachable
len([(v.layer, v.node_type, v.seq_idx) for v in circ_graph.seq_nodes if v.reachable]) / len(circ_graph.seq_nodes)
# Out:
# 1.0
